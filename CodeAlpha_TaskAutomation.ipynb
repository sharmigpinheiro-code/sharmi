# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmigpinheiro-code/sharmi/blob/main/CodeAlpha_TaskAutomation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil

source_folder = "source_images"
destination_folder = "moved_images"

os.makedirs(source_folder, exist_ok=True)
os.makedirs(destination_folder, exist_ok=True)

sample_files = ["photo1.jpg", "photo2.jpg", "image.png", "photo3.jpg"]

for file in sample_files:
    with open(os.path.join(source_folder, file), 'w') as f:
        f.write("sample file")

for filename in os.listdir(source_folder):
    if filename.endswith(".jpg"):
        source_path = os.path.join(source_folder, filename)
        destination_path = os.path.join(destination_folder, filename)

        shutil.move(source_path, destination_path)
        print(f"Moved: {filename}")

print("JPG files moved successfully!")
# Out:
# Moved: photo1.jpg
# Moved: photo3.jpg
# Moved: photo2.jpg
# JPG files moved successfully!
